# %% [markdown]
# **IS362 - Week 8 Assignment**
#
# Your task in this week’s assignment is to load a dataset, perform some minor cleanup and transformation tasks, then use exploratory data analysis to learn about the distribution of variables and the relationship between variables.
# Here is a link to the “Auto MPG” dataset in the UC Irvine data repository: https://archive.ics.uci.edu/ml/datasets/Auto+MPG

# %%
#Loaded libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# **Steps 1 to 3 of the assignment**
#
# 1)load auto-mpg.data
#
# 2)review the data
#
# 3)Use the attribute information provided in auto-mpg.names to name your pandas
# DataFrame columns.

# %%
auto_columns = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model', 'origin', 'car name']
auto_data = pd.read_fwf('https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data', header= None, names= auto_columns)
auto_data = auto_data.set_index("car name")
auto_data
# Out:
#                                      mpg  cylinders  displacement horsepower  \
# car name
# "chevrolet chevelle malibu"         18.0          8         307.0      130.0
# "buick skylark 320"                 15.0          8         350.0      165.0
# "plymouth satellite"                18.0          8         318.0      150.0
# "amc rebel sst"                     16.0          8         304.0      150.0
# "ford torino"                       17.0          8         302.0      140.0
# "ford galaxie 500"                  15.0          8         429.0      198.0
# "chevrolet impala"                  14.0          8         454.0      220.0
# "plymouth fury iii"                 14.0          8         440.0      215.0
# "pontiac catalina"                  14.0          8         455.0      225.0
# "amc ambassador dpl"                15.0          8         390.0      190.0
# "dodge challenger se"               15.0          8         383.0      170.0
# ...

# %% [markdown]
# After reading the data i checked to see if the columns were matched to the names of the data file. In addition, i also checked to see if the index had all the car names.

# %%
auto_data.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model', 'origin'],
#       dtype='object')

# %%
auto_data.index
# Out:
# Index(['"chevrolet chevelle malibu"', '"buick skylark 320"',
#        '"plymouth satellite"', '"amc rebel sst"', '"ford torino"',
#        '"ford galaxie 500"', '"chevrolet impala"', '"plymouth fury iii"',
#        '"pontiac catalina"', '"amc ambassador dpl"',
#        ...
#        '"chrysler lebaron medallion"', '"ford granada l"',
#        '"toyota celica gt"', '"dodge charger 2.2"', '"chevrolet camaro"',
#        '"ford mustang gl"', '"vw pickup"', '"dodge rampage"', '"ford ranger"',
#        '"chevy s-10"'],
#       dtype='object', name='car name', length=398)

# %% [markdown]
# **4. Some of the horsepower data is marked as missing with a ‘?’. You need to replace this ‘?’
# with a pandas-appropriate missing value, then convert the column to numeric.**
#
# I managed to fix the '?' in panadas with NaN using 'replace'.

# %%
auto_data = auto_data.replace(to_replace='?', value=np.nan)

# %% [markdown]
# **5.The origin column values are 1, 2, and 3. Convert these values respectively to ‘USA’, ‘Asia’, and ‘Europe’**
# selected column within the dataframe and replaced the 1,2, and 3 values.

# %%
auto_data['origin'].replace(1, 'USA', inplace=True)
auto_data['origin'].replace(2, 'ASIA', inplace=True)
auto_data['origin'].replace(3, 'EUROPE', inplace=True)

# %%
auto_data
# Out:
#                                      mpg  cylinders  displacement horsepower  \
# car name
# "chevrolet chevelle malibu"         18.0          8         307.0      130.0
# "buick skylark 320"                 15.0          8         350.0      165.0
# "plymouth satellite"                18.0          8         318.0      150.0
# "amc rebel sst"                     16.0          8         304.0      150.0
# "ford torino"                       17.0          8         302.0      140.0
# "ford galaxie 500"                  15.0          8         429.0      198.0
# "chevrolet impala"                  14.0          8         454.0      220.0
# "plymouth fury iii"                 14.0          8         440.0      215.0
# "pontiac catalina"                  14.0          8         455.0      225.0
# "amc ambassador dpl"                15.0          8         390.0      190.0
# "dodge challenger se"               15.0          8         383.0      170.0
# ...

# %% [markdown]
# **6.Create a bar chart that shows the distribution for cylinders.**
#
# Note the index is all the car models.

# %%
auto_data.groupby("cylinders")
auto_data['cylinders'].plot(kind='barh', title="distribution of cylinders")

# %% [markdown]
# Added this extra bar graph to plot the data without the index.

# %%
auto_data.groupby("cylinders").size().plot(kind="bar")

# %% [markdown]
# **7. Create a scatterplot that shows the relationship between horsepower and weight**
#
# Used the scatterplot to show power to weight ration amongst cars.

# %%
plt.scatter(auto_data['horsepower'], auto_data['weight'])
plt.suptitle('Horsepower and Weight')
plt.show()

# %% [markdown]
# **8. Ask, then answer (using matplotlib andseaborn graphics capabilities) an interesting question about the
# distribution of one of the variables, or the relationship between two (or more!) of the variables in the “Auto MPG”
# dataset.**
#
# Using Seaborn i was able to display the linear regression between the car manufaturer(Origin), mpg, and acceleration. If you can't see the graph yo might have to download it and double click on the link.

# %%
sns.factorplot(data=auto_data, 
                       x='origin', 
                       y='mpg', 
                       col='acceleration')

# %% [markdown]
# **Conclusion**

# %% [markdown]
# This assignment showcases the functionality of Pandas compared to using tools such like SQL and Tableau for data analytics. One can use the plot and seaborn packages that pandas has to offer in order to vizualize the data which is crutial. if you have so much data sometimes it needs visual queues.
